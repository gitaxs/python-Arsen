# %%
Алгоритм пулл реквеста. 18.12.2023

1. Найти например какой нибудь проект у коллег
2. Сделать форк 
3. Клонировать проект в Vscode
4. Нажать на поиск, выбрать данный проект
5. Открыть в open new Window 
6. Написать код или оставить коммент
7. Перейти в source control 
8. оставить комент и нажать commit and push 
9. потом в гитхабе перейти в пул реквест у себя
10. отправить пул реквест
11. написать в чатике прими пул
