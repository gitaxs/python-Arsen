# %%
# data analyst - могу ли я проводить eda(разведовательный или первичный анализ данных) анализ на пандасе, с целью помочь отделу аналитики. 
# Для оптимизации их работ, так как на пайтоне для проведения более подробного анализа данных и для интерграций отчетности в приложении и веб сервисы. 
# На Пандасе это возможно. и на пандасе можно работь с базой данной напрямую и выводить красивые графики на подобии в tableu 
# Так же пандас можно интрегрировать анализ и графики в веб-приложения написанные на django и flusk
# Запросить тестовое задание, разобрать с Русланом.
